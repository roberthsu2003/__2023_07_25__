# %%
import random
def get_score() -> list:
    score = []
    for i in range(5):
        score.append(random.randint(50, 100))
    return score

def get_names(nums:int) -> list:
    with open('names.txt',encoding='utf-8',newline='') as file:
        names_str = file.read()
        all_names_list = names_str.split(sep="\n")
        names_list = random.choices(all_names_list,k=nums) #取出一定數量的姓名
    return names_list

nums_int = int(input("請輸入學生數:"))
#取得nums_int個姓名
names_list = get_names(nums_int)
students = []
for i in range(nums_int):
    scores = get_score()
    new_list = [names_list[i]] + scores
    students.append(new_list)
students
# Out:
# [['許芳如', 94, 99, 51, 61, 64],
#  ['陳凱翔', 51, 88, 59, 84, 90],
#  ['詹忠光', 77, 50, 65, 60, 97],
#  ['陳樂紫', 73, 86, 96, 94, 64],
#  ['潘英迪', 64, 64, 61, 96, 95],
#  ['李美洋', 96, 68, 68, 95, 78],
#  ['陳怡容', 68, 71, 66, 82, 99],
#  ['錢欣潔', 51, 51, 52, 68, 60],
#  ['林佳光', 100, 74, 98, 93, 57],
#  ['戚亨', 51, 74, 81, 85, 69],
#  ['謝水儒', 76, 58, 88, 59, 72],
#  ['林志喜', 87, 73, 85, 62, 78],
#  ['林清英', 91, 70, 74, 77, 73],
#  ['蔡世馨', 75, 65, 59, 100, 70],
#  ['吳志宣', 100, 57, 81, 51, 69],
#  ['盧冠發', 68, 77, 86, 69, 95],
#  ['郭致恬', 67, 57, 63, 61, 59],
#  ['王梅劭', 82, 54, 76, 94, 77],
#  ['陳建香', 50, 58, 59, 70, 53],
#  ['方筠紹', 68, 80, 56, 77, 77],
#  ['劉佳佩', 66, 77, 85, 56, 62],
#  ['周怡啟', 69, 85, 75, 62, 93],
#  ['張嘉韋', 53, 54, 68, 55, 73],
#  ['黃佩玲', 100, 76, 75, 78, 72],
#  ['翁羽威', 52, 67, 100, 99, 76],
#  ['李雅怡', 77, 85, 89, 100, 78],
#  ['余丞苓', 93, 74, 83, 69, 71],
#  ['錢欣潔', 51, 77, 88, 75, 92],
#  ['彭虹屏', 61, 99, 59, 57, 69],
#  ['郭舜昇', 94, 73, 67, 58, 76],
#  ['劉萬季', 55, 58, 99, 84, 92],
#  ['簡美君', 79, 65, 73, 57, 58],
#  ['吳麗卿', 99, 72, 81, 82, 62],
#  ['王志謙', 100, 67, 55, 88, 99],
#  ['高俊男', 58, 97, 61, 64, 74],
#  ['楊又源', 60, 96, 61, 87, 54],
#  ['周家銘', 62, 62, 98, 80, 56],
#  ['白美珍', 90, 89, 59, 62, 93],
#  ['王志謙', 67, 51, 63, 57, 90],
#  ['王柏聖', 57, 97, 62, 98, 70],
#  ['李立偉', 76, 91, 95, 71, 58],
#  ['柯韋成', 92, 90, 66, 90, 82],
#  ['王士銘', 65, 59, 76, 65, 85],
#  ['張明惟', 69, 55, 50, 55, 60],
#  ['賴昌韻', 71, 58, 91, 58, 82],
#  ['賴昌韻', 76, 72, 97, 68, 92],
#  ['王孝純', 97, 78, 62, 88, 94],
#  ['謝貞妃', 90, 56, 91, 59, 79],
#  ['陳志偉', 96, 67, 64, 89, 71],
#  ['林冠蕙', 99, 64, 78, 57, 59]]

# %%
import pandas as pd

students_df = pd.DataFrame(students,columns=['姓名','國文','英文','數學','地理','歷史'],index=range(1,nums_int+1))
students_df
# Out:
#      姓名   國文  英文   數學   地理  歷史
# 1   許芳如   94  99   51   61  64
# 2   陳凱翔   51  88   59   84  90
# 3   詹忠光   77  50   65   60  97
# 4   陳樂紫   73  86   96   94  64
# 5   潘英迪   64  64   61   96  95
# 6   李美洋   96  68   68   95  78
# 7   陳怡容   68  71   66   82  99
# 8   錢欣潔   51  51   52   68  60
# 9   林佳光  100  74   98   93  57
# 10   戚亨   51  74   81   85  69
# 11  謝水儒   76  58   88   59  72
# 12  林志喜   87  73   85   62  78
# 13  林清英   91  70   74   77  73
# 14  蔡世馨   75  65   59  100  70
# 15  吳志宣  100  57   81   51  69
# 16  盧冠發   68  77   86   69  95
# 17  郭致恬   67  57   63   61  59
# 18  王梅劭   82  54   76   94  77
# 19  陳建香   50  58   59   70  53
# 20  方筠紹   68  80   56   77  77
# 21  劉佳佩   66  77   85   56  62
# 22  周怡啟   69  85   75   62  93
# 23  張嘉韋   53  54   68   55  73
# 24  黃佩玲  100  76   75   78  72
# 25  翁羽威   52  67  100   99  76
# 26  李雅怡   77  85   89  100  78
# 27  余丞苓   93  74   83   69  71
# 28  錢欣潔   51  77   88   75  92
# 29  彭虹屏   61  99   59   57  69
# 30  郭舜昇   94  73   67   58  76
# 31  劉萬季   55  58   99   84  92
# 32  簡美君   79  65   73   57  58
# 33  吳麗卿   99  72   81   82  62
# 34  王志謙  100  67   55   88  99
# 35  高俊男   58  97   61   64  74
# 36  楊又源   60  96   61   87  54
# 37  周家銘   62  62   98   80  56
# 38  白美珍   90  89   59   62  93
# 39  王志謙   67  51   63   57  90
# 40  王柏聖   57  97   62   98  70
# 41  李立偉   76  91   95   71  58
# 42  柯韋成   92  90   66   90  82
# 43  王士銘   65  59   76   65  85
# 44  張明惟   69  55   50   55  60
# 45  賴昌韻   71  58   91   58  82
# 46  賴昌韻   76  72   97   68  92
# 47  王孝純   97  78   62   88  94
# 48  謝貞妃   90  56   91   59  79
# 49  陳志偉   96  67   64   89  71
# 50  林冠蕙   99  64   78   57  59
