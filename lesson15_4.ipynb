# %%
import numpy as np

student = np.array([67, 78, 92, 74, 65])
student[0]
student[4]
student
# Out:
# array([67, 78, 92, 74, 65])

# %%
import pandas as pd

s1 = pd.Series([67, 78, 92, 74, 65],index=['國文', '英文', '數學', '地理', '歷史'])
s1
# Out:
# 國文    67
# 英文    78
# 數學    92
# 地理    74
# 歷史    65
# dtype: int64

# %%
s1 + 3
# Out:
# 國文    70
# 英文    81
# 數學    95
# 地理    77
# 歷史    68
# dtype: int64

# %%
s1['國文'] #使用key-index
s1[0] #使用原生-index
# Out:
# /tmp/ipykernel_48228/93865201.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s1[0]
# 67

# %%
for i in s1:
    print(i)
# Out:
# 67
# 78
# 92
# 74
# 65

# %%
#numpy的統計,可以套用在pandas
s1
# Out:
# 國文    67
# 英文    78
# 數學    92
# 地理    74
# 歷史    65
# dtype: int64

# %%
#利用numpy的function做統計
np.sum(s1)
# Out:
# 376

# %%
np.mean(s1)
# Out:
# 75.2

# %%
np.std(s1)
# Out:
# 9.620810776644555

# %%
np.median(s1)
# Out:
# 74.0

# %%
s1
# Out:
# 國文    67
# 英文    78
# 數學    92
# 地理    74
# 歷史    65
# dtype: int64

# %%
import pandas as pd
pd.DataFrame({
    "徐國堂":[78, 92, 76, 91, 72],
    "王xx":[72, 81, 92, 94, 69],
    "張xx":[81, 65, 89, 81, 72],
},index=['國文', '英文', '數學', '地理', '歷史'])
# Out:
#     徐國堂  王xx  張xx
# 國文   78   72   81
# 英文   92   81   65
# 數學   76   92   89
# 地理   91   94   81
# 歷史   72   69   72

# %%
import numpy as np
import pandas as pd

data = np.random.randint(60,high=100,size=(50,5))
pd.DataFrame(data,
             index = range(1,51),
             columns=['國文', '英文', '數學', '地理', '歷史']
             )
# Out:
#     國文  英文  數學  地理  歷史
# 1   64  93  89  87  69
# 2   72  90  85  95  96
# 3   81  62  63  98  77
# 4   97  86  74  72  82
# 5   90  63  60  95  74
# 6   61  83  66  81  86
# 7   70  78  77  94  98
# 8   82  86  92  74  70
# 9   90  93  84  73  99
# 10  69  69  76  92  82
# 11  60  67  74  64  88
# 12  64  96  88  86  73
# 13  79  88  68  83  84
# 14  85  97  88  94  93
# 15  76  95  93  99  90
# 16  95  97  76  93  78
# 17  77  81  94  63  86
# 18  89  91  60  99  66
# 19  81  95  65  83  77
# 20  60  61  89  96  73
# 21  71  82  94  94  83
# 22  89  78  82  75  78
# 23  62  94  99  88  80
# 24  97  61  76  75  94
# 25  89  92  83  97  81
# 26  67  85  71  67  87
# 27  71  98  70  69  69
# 28  70  76  66  67  89
# 29  84  60  80  73  63
# 30  60  63  67  86  63
# 31  93  92  83  72  94
# 32  89  86  73  73  63
# 33  81  79  83  84  79
# 34  92  90  84  75  65
# 35  66  70  88  76  65
# 36  71  95  68  74  80
# 37  85  83  82  84  98
# 38  96  86  89  96  86
# 39  90  62  71  78  80
# 40  97  69  91  73  65
# 41  63  88  82  62  87
# 42  77  91  81  94  80
# 43  84  72  88  62  88
# 44  84  76  89  99  63
# 45  94  82  72  70  73
# 46  92  63  71  87  93
# 47  79  73  84  62  75
# 48  68  71  69  82  86
# 49  86  79  76  98  95
# 50  94  79  73  77  60
